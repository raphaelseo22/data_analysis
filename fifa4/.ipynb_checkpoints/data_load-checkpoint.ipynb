# %%
import requests
import pandas as pd

# %%
api_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiNTAwOjEwIiwiYWNjb3VudF9pZCI6IjE5NDYyMzM1NDgiLCJhdXRoX2lkIjoiMiIsImV4cCI6MTY5MzYyMTE3NCwiaWF0IjoxNjc4MDY5MTc0LCJuYmYiOjE2NzgwNjkxNzQsInNlcnZpY2VfaWQiOiI0MzAwMTE0ODEiLCJ0b2tlbl90eXBlIjoiQWNjZXNzVG9rZW4ifQ.HPVse8koaybGZRYgBhaCTlp8GyYeIVfmQaYYtplncsk"

# %%
user_id_url = "https://api.nexon.co.kr/fifaonline4/v1.0/users?nickname=Saniker"

# %%
headers = {"Authorization":api_key}

# %%
user_id = requests.get(user_id_url, headers=headers).json()

# %%
user_id["accessId"]
# Out:
# 'd1452c32297def599c7658f6'

# %%
match_url = f"https://api.nexon.co.kr/fifaonline4/v1.0/users/{user_id['accessId']}/matches?matchtype=50"

# %%
match_list = requests.get(match_url, headers=headers).json()

# %%
match_info_url = f"https://api.nexon.co.kr/fifaonline4/v1.0/matches/{match_list[0]}"

# %%
match_info = requests.get(match_info_url, headers=headers).json()

# %%
match_info["matchInfo"][0]["matchDetail"]["matchResult"]
# Out:
# '패'

# %%
match_info["matchInfo"][0]
# Out:
# {'accessId': 'd1452c32297def599c7658f6',
#  'nickname': 'SanIker',
#  'matchDetail': {'seasonId': 202302,
#   'matchResult': '패',
#   'matchEndType': 0,
#   'systemPause': 0,
#   'foul': 0,
#   'injury': 0,
#   'redCards': 0,
#   'yellowCards': 0,
#   'dribble': 67,
#   'cornerKick': 1,
#   'possession': 45,
#   'offsideCount': 0,
#   'averageRating': 3.93333,
#   'controller': 'gamepad'},
#  'shoot': {'shootTotal': 6,
#   'effectiveShootTotal': 5,
#   'shootOutScore': 0,
#   'goalTotal': 2,
#   'goalTotalDisplay': 2,
#   'ownGoal': 0,
#   'shootHeading': 0,
#   'goalHeading': 0,
#   'shootFreekick': 0,
#   'goalFreekick': 0,
#   'shootInPenalty': 3,
#   'goalInPenalty': 1,
#   'shootOutPenalty': 3,
#   'goalOutPenalty': 1,
#   'shootPenaltyKick': 0,
#   'goalPenaltyKick': 0},
#  'shootDetail': [{'goalTime': 16779421,
#    'x': 0.816359281539917,
#    'y': 0.5248368978500366,
#    'type': 1,
#    'result': 1,
#    'spId': 279239053,
#    'spGrade': 5,
#    'spLevel': 5,
#    'spIdType': True,
#    'assist': True,
#    'assistSpId': 234191695,
#    'assistX': 0.7279686331748962,
#    'assistY': 0.557072103023529,
#    'hitPost': False,
#    'inPenalty': False},
#   {'goalTime': 1701,
#    'x': 0.884269654750824,
#    'y': 0.5985494256019592,
#    'type': 1,
#    'result': 1,
#    'spId': 261005661,
#    'spGrade': 5,
#    'spLevel': 5,
#    'spIdType': True,
#    'assist': True,
#    'assistSpId': 256254642,
#    'assistX': 0.4580063819885254,
#    'assistY': 0.4233990907669067,
#    'hitPost': False,
#    'inPenalty': True},
#   {'goalTime': 16778232,
#    'x': 0.8036869168281555,
#    'y': 0.4849203824996948,
#    'type': 2,
#    'result': 2,
#    'spId': 234191695,
#    'spGrade': 8,
#    'spLevel': 4,
#    'spIdType': True,
#    'assist': True,
#    'assistSpId': 261005661,
#    'assistX': 0.7259054183959961,
#    'assistY': 0.5905472636222839,
#    'hitPost': False,
#    'inPenalty': False},
#   {'goalTime': 16779552,
#    'x': 0.8378481268882751,
#    'y': 0.4971621632575989,
#    'type': 2,
#    'result': 3,
#    'spId': 234191695,
#    'spGrade': 8,
#    'spLevel': 4,
#    'spIdType': True,
#    'assist': True,
#    'assistSpId': 261005661,
#    'assistX': 0.7894080281257629,
#    'assistY': 0.4687038958072662,
#    'hitPost': False,
#    'inPenalty': False},
#   {'goalTime': 413,
#    'x': 0.8434149622917175,
#    'y': 0.5119944214820862,
#    'type': 2,
#    'result': 3,
#    'spId': 256254642,
#    'spGrade': 5,
#    'spLevel': 5,
#    'spIdType': True,
#    'assist': True,
#    'assistSpId': 274200724,
#    'assistX': 0.8305686116218567,
#    'assistY': 0.4549206793308258,
#    'hitPost': False,
#    'inPenalty': True},
#   {'goalTime': 281,
#    'x': 0.9080286026000975,
#    'y': 0.3542532026767731,
#    'type': 2,
#    'result': 1,
#    'spId': 234191695,
#    'spGrade': 8,
#    'spLevel': 4,
#    'spIdType': True,
#    'assist': True,
#    'assistSpId': 261005661,
#    'assistX': 0.5040387511253357,
#    'assistY': 0.4551282227039337,
#    'hitPost': False,
#    'inPenalty': True}],
#  'pass': {'passTry': 95,
#   'passSuccess': 84,
#   'shortPassTry': 73,
#   'shortPassSuccess': 67,
#   'longPassTry': 5,
#   'longPassSuccess': 3,
#   'bouncingLobPassTry': 0,
#   'bouncingLobPassSuccess': 0,
#   'drivenGroundPassTry': 0,
#   'drivenGroundPassSuccess': 0,
#   'throughPassTry': 17,
#   'throughPassSuccess': 14,
#   'lobbedThroughPassTry': 0,
#   'lobbedThroughPassSuccess': 0},
#  'defence': {'blockTry': 11,
#   'blockSuccess': 1,
#   'tackleTry': 19,
#   'tackleSuccess': 8},
#  'player': [{'spId': 234155862,
#    'spPosition': 6,
#    'spGrade': 5,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 4,
#     'defending': 0,
#     'passTry': 5,
#     'passSuccess': 5,
#     'dribbleTry': 2,
#     'dribbleSuccess': 2,
#     'ballPossesionTry': 3,
#     'ballPossesionSuccess': 3,
#     'aerialTry': 1,
#     'aerialSuccess': 0,
#     'blockTry': 1,
#     'block': 1,
#     'tackleTry': 3,
#     'tackle': 3,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 6.4}},
#   {'spId': 210197781,
#    'spPosition': 28,
#    'spGrade': 5,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 0,
#     'passSuccess': 0,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 0,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 0.0}},
#   {'spId': 260200145,
#    'spPosition': 13,
#    'spGrade': 5,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 15,
#     'passSuccess': 13,
#     'dribbleTry': 9,
#     'dribbleSuccess': 9,
#     'ballPossesionTry': 2,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 1,
#     'aerialSuccess': 0,
#     'blockTry': 2,
#     'block': 0,
#     'tackleTry': 1,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 5.8}},
#   {'spId': 274200724,
#    'spPosition': 1,
#    'spGrade': 5,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 1,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 1,
#     'defending': 0,
#     'passTry': 8,
#     'passSuccess': 7,
#     'dribbleTry': 2,
#     'dribbleSuccess': 2,
#     'ballPossesionTry': 3,
#     'ballPossesionSuccess': 3,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 1,
#     'block': 0,
#     'tackleTry': 3,
#     'tackle': 1,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 6.5}},
#   {'spId': 210201535,
#    'spPosition': 4,
#    'spGrade': 8,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 1,
#     'defending': 0,
#     'passTry': 5,
#     'passSuccess': 5,
#     'dribbleTry': 2,
#     'dribbleSuccess': 2,
#     'ballPossesionTry': 2,
#     'ballPossesionSuccess': 2,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 1,
#     'block': 0,
#     'tackleTry': 3,
#     'tackle': 1,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 5.7}},
#   {'spId': 274208618,
#    'spPosition': 28,
#    'spGrade': 3,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 0,
#     'passSuccess': 0,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 0,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 0.0}},
#   {'spId': 214005479,
#    'spPosition': 28,
#    'spGrade': 3,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 0,
#     'passSuccess': 0,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 0,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 0.0}},
#   {'spId': 261005661,
#    'spPosition': 25,
#    'spGrade': 5,
#    'status': {'shoot': 1,
#     'effectiveShoot': 1,
#     'assist': 1,
#     'goal': 0,
#     'dribble': 232,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 18,
#     'passSuccess': 15,
#     'dribbleTry': 12,
#     'dribbleSuccess': 11,
#     'ballPossesionTry': 5,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 2,
#     'aerialSuccess': 0,
#     'blockTry': 1,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 7.8}},
#   {'spId': 234161840,
#    'spPosition': 28,
#    'spGrade': 5,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 0,
#     'passSuccess': 0,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 0,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 0.0}},
#   {'spId': 237165153,
#    'spPosition': 28,
#    'spGrade': 5,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 0,
#     'passSuccess': 0,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 0,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 0.0}},
#   {'spId': 237176676,
#    'spPosition': 8,
#    'spGrade': 6,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 5,
#     'passSuccess': 5,
#     'dribbleTry': 2,
#     'dribbleSuccess': 2,
#     'ballPossesionTry': 2,
#     'ballPossesionSuccess': 2,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 1,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 4.9}},
#   {'spId': 234191695,
#    'spPosition': 20,
#    'spGrade': 8,
#    'status': {'shoot': 3,
#     'effectiveShoot': 2,
#     'assist': 0,
#     'goal': 1,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 10,
#     'passSuccess': 9,
#     'dribbleTry': 16,
#     'dribbleSuccess': 11,
#     'ballPossesionTry': 6,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 1,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 8.1}},
#   {'spId': 242192119,
#    'spPosition': 0,
#    'spGrade': 7,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 4,
#     'passTry': 2,
#     'passSuccess': 2,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 3,
#     'ballPossesionSuccess': 3,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 6.2}},
#   {'spId': 260204963,
#    'spPosition': 2,
#    'spGrade': 5,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 2,
#     'defending': 0,
#     'passTry': 10,
#     'passSuccess': 8,
#     'dribbleTry': 4,
#     'dribbleSuccess': 4,
#     'ballPossesionTry': 6,
#     'ballPossesionSuccess': 4,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 2,
#     'block': 0,
#     'tackleTry': 3,
#     'tackle': 2,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 6.1}},
#   {'spId': 215238794,
#    'spPosition': 28,
#    'spGrade': 1,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 0,
#     'passSuccess': 0,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 0,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 0.0}},
#   {'spId': 279239053,
#    'spPosition': 15,
#    'spGrade': 5,
#    'status': {'shoot': 1,
#     'effectiveShoot': 1,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 112,
#     'intercept': 1,
#     'defending': 0,
#     'passTry': 7,
#     'passSuccess': 7,
#     'dribbleTry': 5,
#     'dribbleSuccess': 4,
#     'ballPossesionTry': 5,
#     'ballPossesionSuccess': 3,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 2,
#     'block': 0,
#     'tackleTry': 3,
#     'tackle': 1,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 5.8}},
#   {'spId': 215240130,
#    'spPosition': 28,
#    'spGrade': 2,
#    'status': {'shoot': 0,
#     'effectiveShoot': 0,
#     'assist': 0,
#     'goal': 0,
#     'dribble': 0,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 0,
#     'passSuccess': 0,
#     'dribbleTry': 0,
#     'dribbleSuccess': 0,
#     'ballPossesionTry': 0,
#     'ballPossesionSuccess': 0,
#     'aerialTry': 0,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 0,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 0.0}},
#   {'spId': 256254642,
#    'spPosition': 22,
#    'spGrade': 5,
#    'status': {'shoot': 1,
#     'effectiveShoot': 1,
#     'assist': 0,
#     'goal': 1,
#     'dribble': 39,
#     'intercept': 0,
#     'defending': 0,
#     'passTry': 10,
#     'passSuccess': 8,
#     'dribbleTry': 13,
#     'dribbleSuccess': 10,
#     'ballPossesionTry': 8,
#     'ballPossesionSuccess': 1,
#     'aerialTry': 1,
#     'aerialSuccess': 0,
#     'blockTry': 0,
#     'block': 0,
#     'tackleTry': 2,
#     'tackle': 0,
#     'yellowCards': 0,
#     'redCards': 0,
#     'spRating': 7.5}}]}

# %%
matchResult = match_info["matchInfo"][0]["matchDetail"]["matchResult"]
seasonId = match_info["matchInfo"][0]["matchDetail"]["seasonId"]
controller = match_info["matchInfo"][0]["matchDetail"]["controller"]
shootDetail = match_info["matchInfo"][0]["shootDetail"]
player = match_info["matchInfo"][0]["player"]

# %%
player
# Out:
# [{'spId': 234155862,
#   'spPosition': 6,
#   'spGrade': 5,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 4,
#    'defending': 0,
#    'passTry': 5,
#    'passSuccess': 5,
#    'dribbleTry': 2,
#    'dribbleSuccess': 2,
#    'ballPossesionTry': 3,
#    'ballPossesionSuccess': 3,
#    'aerialTry': 1,
#    'aerialSuccess': 0,
#    'blockTry': 1,
#    'block': 1,
#    'tackleTry': 3,
#    'tackle': 3,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 6.4}},
#  {'spId': 210197781,
#   'spPosition': 28,
#   'spGrade': 5,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 0,
#    'passSuccess': 0,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 0,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 0.0}},
#  {'spId': 260200145,
#   'spPosition': 13,
#   'spGrade': 5,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 15,
#    'passSuccess': 13,
#    'dribbleTry': 9,
#    'dribbleSuccess': 9,
#    'ballPossesionTry': 2,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 1,
#    'aerialSuccess': 0,
#    'blockTry': 2,
#    'block': 0,
#    'tackleTry': 1,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 5.8}},
#  {'spId': 274200724,
#   'spPosition': 1,
#   'spGrade': 5,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 1,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 1,
#    'defending': 0,
#    'passTry': 8,
#    'passSuccess': 7,
#    'dribbleTry': 2,
#    'dribbleSuccess': 2,
#    'ballPossesionTry': 3,
#    'ballPossesionSuccess': 3,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 1,
#    'block': 0,
#    'tackleTry': 3,
#    'tackle': 1,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 6.5}},
#  {'spId': 210201535,
#   'spPosition': 4,
#   'spGrade': 8,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 1,
#    'defending': 0,
#    'passTry': 5,
#    'passSuccess': 5,
#    'dribbleTry': 2,
#    'dribbleSuccess': 2,
#    'ballPossesionTry': 2,
#    'ballPossesionSuccess': 2,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 1,
#    'block': 0,
#    'tackleTry': 3,
#    'tackle': 1,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 5.7}},
#  {'spId': 274208618,
#   'spPosition': 28,
#   'spGrade': 3,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 0,
#    'passSuccess': 0,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 0,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 0.0}},
#  {'spId': 214005479,
#   'spPosition': 28,
#   'spGrade': 3,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 0,
#    'passSuccess': 0,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 0,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 0.0}},
#  {'spId': 261005661,
#   'spPosition': 25,
#   'spGrade': 5,
#   'status': {'shoot': 1,
#    'effectiveShoot': 1,
#    'assist': 1,
#    'goal': 0,
#    'dribble': 232,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 18,
#    'passSuccess': 15,
#    'dribbleTry': 12,
#    'dribbleSuccess': 11,
#    'ballPossesionTry': 5,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 2,
#    'aerialSuccess': 0,
#    'blockTry': 1,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 7.8}},
#  {'spId': 234161840,
#   'spPosition': 28,
#   'spGrade': 5,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 0,
#    'passSuccess': 0,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 0,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 0.0}},
#  {'spId': 237165153,
#   'spPosition': 28,
#   'spGrade': 5,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 0,
#    'passSuccess': 0,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 0,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 0.0}},
#  {'spId': 237176676,
#   'spPosition': 8,
#   'spGrade': 6,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 5,
#    'passSuccess': 5,
#    'dribbleTry': 2,
#    'dribbleSuccess': 2,
#    'ballPossesionTry': 2,
#    'ballPossesionSuccess': 2,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 1,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 4.9}},
#  {'spId': 234191695,
#   'spPosition': 20,
#   'spGrade': 8,
#   'status': {'shoot': 3,
#    'effectiveShoot': 2,
#    'assist': 0,
#    'goal': 1,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 10,
#    'passSuccess': 9,
#    'dribbleTry': 16,
#    'dribbleSuccess': 11,
#    'ballPossesionTry': 6,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 1,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 8.1}},
#  {'spId': 242192119,
#   'spPosition': 0,
#   'spGrade': 7,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 4,
#    'passTry': 2,
#    'passSuccess': 2,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 3,
#    'ballPossesionSuccess': 3,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 6.2}},
#  {'spId': 260204963,
#   'spPosition': 2,
#   'spGrade': 5,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 2,
#    'defending': 0,
#    'passTry': 10,
#    'passSuccess': 8,
#    'dribbleTry': 4,
#    'dribbleSuccess': 4,
#    'ballPossesionTry': 6,
#    'ballPossesionSuccess': 4,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 2,
#    'block': 0,
#    'tackleTry': 3,
#    'tackle': 2,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 6.1}},
#  {'spId': 215238794,
#   'spPosition': 28,
#   'spGrade': 1,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 0,
#    'passSuccess': 0,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 0,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 0.0}},
#  {'spId': 279239053,
#   'spPosition': 15,
#   'spGrade': 5,
#   'status': {'shoot': 1,
#    'effectiveShoot': 1,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 112,
#    'intercept': 1,
#    'defending': 0,
#    'passTry': 7,
#    'passSuccess': 7,
#    'dribbleTry': 5,
#    'dribbleSuccess': 4,
#    'ballPossesionTry': 5,
#    'ballPossesionSuccess': 3,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 2,
#    'block': 0,
#    'tackleTry': 3,
#    'tackle': 1,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 5.8}},
#  {'spId': 215240130,
#   'spPosition': 28,
#   'spGrade': 2,
#   'status': {'shoot': 0,
#    'effectiveShoot': 0,
#    'assist': 0,
#    'goal': 0,
#    'dribble': 0,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 0,
#    'passSuccess': 0,
#    'dribbleTry': 0,
#    'dribbleSuccess': 0,
#    'ballPossesionTry': 0,
#    'ballPossesionSuccess': 0,
#    'aerialTry': 0,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 0,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 0.0}},
#  {'spId': 256254642,
#   'spPosition': 22,
#   'spGrade': 5,
#   'status': {'shoot': 1,
#    'effectiveShoot': 1,
#    'assist': 0,
#    'goal': 1,
#    'dribble': 39,
#    'intercept': 0,
#    'defending': 0,
#    'passTry': 10,
#    'passSuccess': 8,
#    'dribbleTry': 13,
#    'dribbleSuccess': 10,
#    'ballPossesionTry': 8,
#    'ballPossesionSuccess': 1,
#    'aerialTry': 1,
#    'aerialSuccess': 0,
#    'blockTry': 0,
#    'block': 0,
#    'tackleTry': 2,
#    'tackle': 0,
#    'yellowCards': 0,
#    'redCards': 0,
#    'spRating': 7.5}}]

# %%
shootDetail
# Out:
# [{'goalTime': 16779421,
#   'x': 0.816359281539917,
#   'y': 0.5248368978500366,
#   'type': 1,
#   'result': 1,
#   'spId': 279239053,
#   'spGrade': 5,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 234191695,
#   'assistX': 0.7279686331748962,
#   'assistY': 0.557072103023529,
#   'hitPost': False,
#   'inPenalty': False},
#  {'goalTime': 1701,
#   'x': 0.884269654750824,
#   'y': 0.5985494256019592,
#   'type': 1,
#   'result': 1,
#   'spId': 261005661,
#   'spGrade': 5,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 256254642,
#   'assistX': 0.4580063819885254,
#   'assistY': 0.4233990907669067,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 16778232,
#   'x': 0.8036869168281555,
#   'y': 0.4849203824996948,
#   'type': 2,
#   'result': 2,
#   'spId': 234191695,
#   'spGrade': 8,
#   'spLevel': 4,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 261005661,
#   'assistX': 0.7259054183959961,
#   'assistY': 0.5905472636222839,
#   'hitPost': False,
#   'inPenalty': False},
#  {'goalTime': 16779552,
#   'x': 0.8378481268882751,
#   'y': 0.4971621632575989,
#   'type': 2,
#   'result': 3,
#   'spId': 234191695,
#   'spGrade': 8,
#   'spLevel': 4,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 261005661,
#   'assistX': 0.7894080281257629,
#   'assistY': 0.4687038958072662,
#   'hitPost': False,
#   'inPenalty': False},
#  {'goalTime': 413,
#   'x': 0.8434149622917175,
#   'y': 0.5119944214820862,
#   'type': 2,
#   'result': 3,
#   'spId': 256254642,
#   'spGrade': 5,
#   'spLevel': 5,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 274200724,
#   'assistX': 0.8305686116218567,
#   'assistY': 0.4549206793308258,
#   'hitPost': False,
#   'inPenalty': True},
#  {'goalTime': 281,
#   'x': 0.9080286026000975,
#   'y': 0.3542532026767731,
#   'type': 2,
#   'result': 1,
#   'spId': 234191695,
#   'spGrade': 8,
#   'spLevel': 4,
#   'spIdType': True,
#   'assist': True,
#   'assistSpId': 261005661,
#   'assistX': 0.5040387511253357,
#   'assistY': 0.4551282227039337,
#   'hitPost': False,
#   'inPenalty': True}]

# %%
for p in match_info["matchInfo"][0]["player"]:
    if p["spPosition"] == 0:
        targetId = p["spId"]
        print(p["spId"])
# Out:
# 242192119

# %%
spid_url = "https://static.api.nexon.co.kr/fifaonline4/latest/spid.json"

# %%
spid_list = requests.get(spid_url, headers=headers).json()

# %%
for spid in spid_list:
    if spid["id"] == targetId:
        print(spid["name"])
# Out:
# 티보 쿠르투아
