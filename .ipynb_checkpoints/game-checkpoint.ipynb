# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("vgsales.csv")

# %% [markdown]
# ## 가설
# 1. 나라별로 선호하는 플랫폼과 게임 장르 및 퍼블리셔가 다를 것이다
# 2. 북미 판매량이 세계 판매량과 가장 밀접한 관계가 있을 것이다
# 3. 각 시기별 인기있는 플랫폼과 장르가 다를 것
# 4. 위의 가설들을 바탕으로 게임 어느 지역에서 더 많이 판매될 것인가를 예측할 수 있을 것이다

# %%
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# ### 데이터 설명
# - vgchartz.com 기준 100,000장 이상 팔린 게임들의 판매량 및 세부 데이터
#   - Rank : 가장 많이 팔린 순위
#   - Name : 게임의 제목
#   - Platform : 게임이 발매된 플랫폼 e.g)pc, ps4, ...
#   - Year : 게임이 발매된 해
#   - Genre : 게임의 장르
#   - Publisher : 게임의 퍼블리셔
#   - NA,EU,JP_sales : 미국, 유럽, 일본 각각 지역의 판매량 (in million)
#   - Other_sales : 미국, 유럽, 일본을 제외한 지역의 판매량 (in million)
#   - Global_sales : 전 세계 판매량 (in million)

# %%
best_region = []

# %%
sales = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]
for i in range(len(data)):
    if data[sales].iloc[i].max() == data["NA_Sales"].iloc[i]:
        best_region.append("NA")
    elif data[sales].iloc[i].max() == data["EU_Sales"].iloc[i]:
        best_region.append("EU")
    elif data[sales].iloc[i].max() == data["JP_Sales"].iloc[i]:
        best_region.append("JP")
    else:
        best_region.append("Other")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data, best_region, test_size=0.3, random_state=14)

# %%
X_train.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            193
# Genre             0
# Publisher        46
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
X_train.Genre.value_counts()
# Out:
# Action          2329
# Sports          1608
# Misc            1204
# Role-Playing    1072
# Shooter          944
# Adventure        892
# Racing           877
# Platform         619
# Simulation       608
# Fighting         581
# Strategy         483
# Puzzle           401
# Name: Genre, dtype: int64

# %%
genr_dict = {G:idx for idx, G in enumerate(X_train.Genre.value_counts().keys())}

# %%
genr_dict_str = {v:k for k, v in genr_dict.items()}

# %%
genr_dict
# Out:
# {'Action': 0,
#  'Sports': 1,
#  'Misc': 2,
#  'Role-Playing': 3,
#  'Shooter': 4,
#  'Adventure': 5,
#  'Racing': 6,
#  'Platform': 7,
#  'Simulation': 8,
#  'Fighting': 9,
#  'Strategy': 10,
#  'Puzzle': 11}

# %%
genr_dict_str
# Out:
# {0: 'Action',
#  1: 'Sports',
#  2: 'Misc',
#  3: 'Role-Playing',
#  4: 'Shooter',
#  5: 'Adventure',
#  6: 'Racing',
#  7: 'Platform',
#  8: 'Simulation',
#  9: 'Fighting',
#  10: 'Strategy',
#  11: 'Puzzle'}

# %%
X_train.Platform.value_counts()
# Out:
# DS      1489
# PS2     1472
# PS3      963
# Wii      950
# X360     881
# PSP      875
# PS       842
# PC       679
# GBA      583
# XB       576
# GC       383
# 3DS      349
# PSV      285
# PS4      237
# N64      225
# SNES     170
# XOne     143
# SAT      114
# WiiU     102
# 2600      87
# GB        73
# NES       68
# DC        32
# GEN       21
# NG         7
# WS         4
# SCD        3
# 3DO        2
# PCFX       1
# GG         1
# TG16       1
# Name: Platform, dtype: int64

# %%
plat_dict = {p:idx for idx, p in enumerate(X_train.Platform.value_counts().keys())}

# %%
plat_dict
# Out:
# {'DS': 0,
#  'PS2': 1,
#  'PS3': 2,
#  'Wii': 3,
#  'X360': 4,
#  'PSP': 5,
#  'PS': 6,
#  'PC': 7,
#  'GBA': 8,
#  'XB': 9,
#  'GC': 10,
#  '3DS': 11,
#  'PSV': 12,
#  'PS4': 13,
#  'N64': 14,
#  'SNES': 15,
#  'XOne': 16,
#  'SAT': 17,
#  'WiiU': 18,
#  '2600': 19,
#  'GB': 20,
#  'NES': 21,
#  'DC': 22,
#  'GEN': 23,
#  'NG': 24,
#  'WS': 25,
#  'SCD': 26,
#  '3DO': 27,
#  'PCFX': 28,
#  'GG': 29,
#  'TG16': 30}

# %%
plat_dict_str = {v:k for k, v in plat_dict.items()}

# %%
plat_dict_str
# Out:
# {0: 'DS',
#  1: 'PS2',
#  2: 'PS3',
#  3: 'Wii',
#  4: 'X360',
#  5: 'PSP',
#  6: 'PS',
#  7: 'PC',
#  8: 'GBA',
#  9: 'XB',
#  10: 'GC',
#  11: '3DS',
#  12: 'PSV',
#  13: 'PS4',
#  14: 'N64',
#  15: 'SNES',
#  16: 'XOne',
#  17: 'SAT',
#  18: 'WiiU',
#  19: '2600',
#  20: 'GB',
#  21: 'NES',
#  22: 'DC',
#  23: 'GEN',
#  24: 'NG',
#  25: 'WS',
#  26: 'SCD',
#  27: '3DO',
#  28: 'PCFX',
#  29: 'GG',
#  30: 'TG16'}

# %%
X_train.Publisher.value_counts()
# Out:
# Electronic Arts                 953
# Ubisoft                         662
# Activision                      660
# Namco Bandai Games              625
# Konami Digital Entertainment    586
#                                ...
# Misawa                            1
# Pioneer LDC                       1
# Tigervision                       1
# CTO SpA                           1
# Revolution Software               1
# Name: Publisher, Length: 513, dtype: int64

# %%
pub_dict = {p:(idx if idx <= 30 else 30) for idx, p in enumerate(X_train.Publisher.value_counts().keys())}

# %%
pub_dict
# Out:
# {'Electronic Arts': 0,
#  'Ubisoft': 1,
#  'Activision': 2,
#  'Namco Bandai Games': 3,
#  'Konami Digital Entertainment': 4,
#  'Sony Computer Entertainment': 5,
#  'THQ': 6,
#  'Nintendo': 7,
#  'Sega': 8,
#  'Take-Two Interactive': 9,
#  'Capcom': 10,
#  'Atari': 11,
#  'Tecmo Koei': 12,
#  'Warner Bros. Interactive Entertainment': 13,
#  'Square Enix': 14,
#  'Unknown': 15,
#  'Disney Interactive Studios': 16,
#  'Eidos Interactive': 17,
#  'Midway Games': 18,
#  '505 Games': 19,
#  'Microsoft Game Studios': 20,
#  'D3Publisher': 21,
#  'Acclaim Entertainment': 22,
#  'Vivendi Games': 23,
#  'Codemasters': 24,
#  'Deep Silver': 25,
#  'Idea Factory': 26,
#  'Zoo Digital Publishing': 27,
#  'Nippon Ichi Software': 28,
#  'Hudson Soft': 29,
#  'LucasArts': 30,
#  'Majesco Entertainment': 30,
#  'Rising Star Games': 30,
#  'Bethesda Softworks': 30,
#  '5pb': 30,
#  'Atlus': 30,
#  'Crave Entertainment': 30,
#  'Banpresto': 30,
#  'Ignition Entertainment': 30,
#  'Empire Interactive': 30,
#  'Infogrames': 30,
#  'Focus Home Interactive': 30,
#  'Virgin Interactive': 30,
#  'Marvelous Interactive': 30,
#  'SquareSoft': 30,
#  'GT Interactive': 30,
#  'Kadokawa Shoten': 30,
#  'DTP Entertainment': 30,
#  'Destineer': 30,
#  'Global Star': 30,
#  'SouthPeak Games': 30,
#  '3DO': 30,
#  'Takara Tomy': 30,
#  'Spike': 30,
#  'TDK Mediactive': 30,
#  'Alchemist': 30,
#  'PQube': 30,
#  'MTV Games': 30,
#  'BAM! Entertainment': 30,
#  'Black Bean Games': 30,
#  'Game Factory': 30,
#  'Interplay': 30,
#  'Kalypso Media': 30,
#  'Psygnosis': 30,
#  'Enix Corporation': 30,
#  'Prototype': 30,
#  'Arc System Works': 30,
#  'Nordic Games': 30,
#  'Zoo Games': 30,
#  'Mindscape': 30,
#  'Activision Value': 30,
#  'Level 5': 30,
#  'Little Orbit': 30,
#  'Jaleco': 30,
#  'Midas Interactive Entertainment': 30,
#  'JoWood Productions': 30,
#  'Universal Interactive': 30,
#  'Broccoli': 30,
#  'SNK Playmore': 30,
#  'Paradox Interactive': 30,
#  'Oxygen Interactive': 30,
#  'FuRyu': 30,
#  'SNK': 30,
#  'Compile Heart': 30,
#  'Kemco': 30,
#  'Avanquest': 30,
#  'From Software': 30,
#  'O-Games': 30,
#  'Aqua Plus': 30,
#  'Koch Media': 30,
#  'Enterbrain': 30,
#  'GSP': 30,
#  'Telltale Games': 30,
#  'Taito': 30,
#  'Rocket Company': 30,
#  'Tomy Corporation': 30,
#  'Quinrose': 30,
#  'Takara': 30,
#  'UFO Interactive': 30,
#  'Playlogic Game Factory': 30,
#  'Conspiracy Entertainment': 30,
#  'DreamCatcher Interactive': 30,
#  'PopCap Games': 30,
#  'Success': 30,
#  'Kadokawa Games': 30,
#  'Milestone S.r.l.': 30,
#  'Ubisoft Annecy': 30,
#  'Zushi Games': 30,
#  'Marvelous Entertainment': 30,
#  'Rondomedia': 30,
#  'Falcom Corporation': 30,
#  'Titus': 30,
#  'Bigben Interactive': 30,
#  'City Interactive': 30,
#  'Storm City Games': 30,
#  '989 Studios': 30,
#  'ASCII Entertainment': 30,
#  'Hasbro Interactive': 30,
#  'System 3 Arcade Software': 30,
#  'ChunSoft': 30,
#  'CyberFront': 30,
#  'Ocean': 30,
#  'Mastertronic': 30,
#  'Ghostlight': 30,
#  'Sony Computer Entertainment Europe': 30,
#  'Play It': 30,
#  'Gust': 30,
#  'Imagineer': 30,
#  'SCi': 30,
#  'Nobilis': 30,
#  'Human Entertainment': 30,
#  'Hudson Entertainment': 30,
#  'GungHo': 30,
#  'Natsume': 30,
#  'Scholastic Inc.': 30,
#  'Mastiff': 30,
#  'Destination Software, Inc': 30,
#  'Microids': 30,
#  'Metro 3D': 30,
#  'Starfish': 30,
#  'Sony Online Entertainment': 30,
#  'Mattel Interactive': 30,
#  'Reef Entertainment': 30,
#  'Acquire': 30,
#  'ASCII Media Works': 30,
#  'Yeti': 30,
#  'NewKidCo': 30,
#  'Asgard': 30,
#  'Ackkstudios': 30,
#  'Victor Interactive': 30,
#  'Fox Interactive': 30,
#  'Cave': 30,
#  'Foreign Media Games': 30,
#  'XS Games': 30,
#  'Avanquest Software': 30,
#  'Aksys Games': 30,
#  'MTO': 30,
#  'Aspyr': 30,
#  'Parker Bros.': 30,
#  'Telegames': 30,
#  'Valcon Games': 30,
#  'Sting': 30,
#  'Nippon Columbia': 30,
#  'Gremlin Interactive Ltd': 30,
#  'LEGO Media': 30,
#  'Alternative Software': 30,
#  'RTL': 30,
#  'Genki': 30,
#  'Xplosiv': 30,
#  'JVC': 30,
#  'Popcorn Arcade': 30,
#  'Idea Factory International': 30,
#  'DSI Games': 30,
#  'NEC Interchannel': 30,
#  'BMG Interactive Entertainment': 30,
#  'Swing! Entertainment': 30,
#  'Screenlife': 30,
#  'Square': 30,
#  'Benesse': 30,
#  'Graffiti': 30,
#  'Epoch': 30,
#  'Rage Software': 30,
#  'Tru Blu Entertainment': 30,
#  'Hackberry': 30,
#  'Evolved Games': 30,
#  'Funbox Media': 30,
#  'Astragon': 30,
#  'Gathering of Developers': 30,
#  'Sunsoft': 30,
#  'ArtDink': 30,
#  'Irem Software Engineering': 30,
#  'Agetec': 30,
#  'Paon': 30,
#  'bitComposer Games': 30,
#  'AQ Interactive': 30,
#  'Video System': 30,
#  'Nordcurrent': 30,
#  'Media Works': 30,
#  'NCSoft': 30,
#  'Blast! Entertainment Ltd': 30,
#  'Microprose': 30,
#  'Big Ben Interactive': 30,
#  'Brash Entertainment': 30,
#  'Nihon Falcom Corporation': 30,
#  'TDK Core': 30,
#  'Neko Entertainment': 30,
#  'System Soft': 30,
#  'Sunrise Interactive': 30,
#  'Kaga Create': 30,
#  'ValuSoft': 30,
#  'Tommo': 30,
#  'Mumbo Jumbo': 30,
#  'Compile': 30,
#  'Mentor Interactive': 30,
#  'dramatic create': 30,
#  'Avalon Interactive': 30,
#  'Laguna': 30,
#  'The Adventure Company': 30,
#  'Gotham Games': 30,
#  '20th Century Fox Video Games': 30,
#  'Global A Entertainment': 30,
#  'Seta Corporation': 30,
#  'IE Institute': 30,
#  'KID': 30,
#  'Funsta': 30,
#  'NovaLogic': 30,
#  'Gamecock': 30,
#  'ESP': 30,
#  'Agatsuma Entertainment': 30,
#  'Ascaron Entertainment GmbH': 30,
#  'Hip Interactive': 30,
#  'Daedalic': 30,
#  'Mad Catz': 30,
#  'Jorudan': 30,
#  'Experience Inc.': 30,
#  'Mojang': 30,
#  'Red Storm Entertainment': 30,
#  'Trion Worlds': 30,
#  'Sony Computer Entertainment America': 30,
#  'Data Design Interactive': 30,
#  'Imagic': 30,
#  'Asylum Entertainment': 30,
#  'Excalibur Publishing': 30,
#  'Sammy Corporation': 30,
#  'Vir2L Studios': 30,
#  "Yuke's": 30,
#  'TGL': 30,
#  'GameMill Entertainment': 30,
#  'CDV Software Entertainment': 30,
#  'MC2 Entertainment': 30,
#  'Angel Studios': 30,
#  'Time Warner Interactive': 30,
#  'Maxis': 30,
#  'Mud Duck Productions': 30,
#  'Pinnacle': 30,
#  'Creative Core': 30,
#  'Licensed 4U': 30,
#  'Wanadoo': 30,
#  'P2 Games': 30,
#  'Touchstone': 30,
#  'Happinet': 30,
#  'Harmonix Music Systems': 30,
#  'Crimson Cow': 30,
#  'Coconuts Japan': 30,
#  'Data Age': 30,
#  'Media Factory': 30,
#  '1C Company': 30,
#  'Focus Multimedia': 30,
#  'HuneX': 30,
#  'Iceberg Interactive': 30,
#  'Telstar': 30,
#  'Arika': 30,
#  'Valve Software': 30,
#  'LSP Games': 30,
#  'Daito': 30,
#  'Indie Games': 30,
#  'Electronic Arts Victor': 30,
#  'TopWare Interactive': 30,
#  'Myelin Media': 30,
#  'Funcom': 30,
#  'Slightly Mad Studios': 30,
#  'Xseed Games': 30,
#  'Cloud Imperium Games Corporation': 30,
#  'Gainax Network Systems': 30,
#  'Crystal Dynamics': 30,
#  'NEC': 30,
#  'Aruze Corp': 30,
#  'Devolver Digital': 30,
#  'Coleco': 30,
#  'Culture Brain': 30,
#  'RedOctane': 30,
#  'Micro Cabin': 30,
#  'Daedalic Entertainment': 30,
#  'System 3': 30,
#  'BPS': 30,
#  'Media Rings': 30,
#  'Rebellion': 30,
#  'Mercury Games': 30,
#  'Vatical Entertainment': 30,
#  'Asmik Ace Entertainment': 30,
#  'Magix': 30,
#  'Princess Soft': 30,
#  'Core Design Ltd.': 30,
#  'Jester Interactive': 30,
#  'DHM Interactive': 30,
#  'Phenomedia': 30,
#  'Minato Station': 30,
#  'Alawar Entertainment': 30,
#  'Insomniac Games': 30,
#  'GN Software': 30,
#  'Mamba Games': 30,
#  'Aerosoft': 30,
#  'Knowledge Adventure': 30,
#  'NCS': 30,
#  'Yamasa Entertainment': 30,
#  'Home Entertainment Suppliers': 30,
#  'Moss': 30,
#  'Comfort': 30,
#  'Encore': 30,
#  '10TACLE Studios': 30,
#  'Edia': 30,
#  'Nippon Telenet': 30,
#  'Tradewest': 30,
#  'Slitherine Software': 30,
#  'Blue Byte': 30,
#  'Accolade': 30,
#  'Russel': 30,
#  'HMH Interactive': 30,
#  'U.S. Gold': 30,
#  'Flashpoint Games': 30,
#  'Sonnet': 30,
#  'Arena Entertainment': 30,
#  'imageepoch Inc.': 30,
#  'Sunflowers': 30,
#  'Ultravision': 30,
#  'Navarre Corp': 30,
#  'Sony Music Entertainment': 30,
#  'Pony Canyon': 30,
#  'Pack-In-Video': 30,
#  'Lighthouse Interactive': 30,
#  'id Software': 30,
#  'TOHO': 30,
#  'GameTek': 30,
#  'Stainless Games': 30,
#  'inXile Entertainment': 30,
#  'Magical Company': 30,
#  'ASK': 30,
#  'Westwood Studios': 30,
#  'GOA': 30,
#  'Men-A-Vision': 30,
#  'Fields': 30,
#  'Data East': 30,
#  'Black Label Games': 30,
#  'Datam Polystar': 30,
#  'Team17 Software': 30,
#  'Pow': 30,
#  'Adeline Software': 30,
#  'Saurus': 30,
#  'RED Entertainment': 30,
#  'Interplay Productions': 30,
#  'Phantagram': 30,
#  'Visco': 30,
#  'ASC Games': 30,
#  'Plenty': 30,
#  '989 Sports': 30,
#  'Takuyo': 30,
#  'Sears': 30,
#  'Imax': 30,
#  'Ongakukan': 30,
#  'Just Flight': 30,
#  'Culture Publishers': 30,
#  'Simon & Schuster Interactive': 30,
#  'Tripwire Interactive': 30,
#  'Otomate': 30,
#  'Virtual Play Games': 30,
#  'Media Entertainment': 30,
#  'Her Interactive': 30,
#  'Ecole': 30,
#  'Karin Entertainment': 30,
#  'Griffin International': 30,
#  'Phantom EFX': 30,
#  'Hamster Corporation': 30,
#  'Marvelous Games': 30,
#  'Milestone': 30,
#  '7G//AMES': 30,
#  'Panther Software': 30,
#  'DigiCube': 30,
#  'Image Epoch': 30,
#  'Performance Designed Products': 30,
#  'PlayV': 30,
#  'Havas Interactive': 30,
#  'Summitsoft': 30,
#  'Activision Blizzard': 30,
#  'Number None': 30,
#  'Aria': 30,
#  'Commseed': 30,
#  'Illusion Softworks': 30,
#  'T&E Soft': 30,
#  'O3 Entertainment': 30,
#  'Masque Publishing': 30,
#  'Quest': 30,
#  'General Entertainment': 30,
#  'FuRyu Corporation': 30,
#  'Red Orb': 30,
#  'Marvel Entertainment': 30,
#  'Ertain': 30,
#  'Gaga': 30,
#  'Valve': 30,
#  'Naxat Soft': 30,
#  'Easy Interactive': 30,
#  'Xicat Interactive': 30,
#  'UIG Entertainment': 30,
#  'Wizard Video Games': 30,
#  'Warashi': 30,
#  'Mitsui': 30,
#  'New': 30,
#  'Altron': 30,
#  'Vic Tokai': 30,
#  'Origin Systems': 30,
#  'Merscom LLC': 30,
#  'Gakken': 30,
#  'Introversion Software': 30,
#  'Lexicon Entertainment': 30,
#  'Giga': 30,
#  'ITT Family Games': 30,
#  'Axela': 30,
#  'Michaelsoft': 30,
#  'Palcom': 30,
#  'Rebellion Developments': 30,
#  'Asmik Corp': 30,
#  'Athena': 30,
#  'Kool Kizz': 30,
#  'Maximum Family Games': 30,
#  'Sold Out': 30,
#  'Zenrin': 30,
#  'Jack of All Games': 30,
#  'TYO': 30,
#  'Tetris Online': 30,
#  'Dusenberry Martin Racing': 30,
#  'Fuji': 30,
#  'Mycom': 30,
#  'MLB.com': 30,
#  'CBS Electronics': 30,
#  'Dorart': 30,
#  'Interworks Unlimited, Inc.': 30,
#  'Interchannel-Holon': 30,
#  'Answer Software': 30,
#  'Nexon': 30,
#  'Locus': 30,
#  'Views': 30,
#  'Nichibutsu': 30,
#  'Pack In Soft': 30,
#  'Hect': 30,
#  'Office Create': 30,
#  'Imageworks': 30,
#  'TalonSoft': 30,
#  'Genterprise': 30,
#  'Riverhillsoft': 30,
#  'NetRevo': 30,
#  'NDA Productions': 30,
#  'PopTop Software': 30,
#  'CPG Products': 30,
#  'Strategy First': 30,
#  'American Softworks': 30,
#  'Kando Games': 30,
#  'Groove Games': 30,
#  'Alvion': 30,
#  'Giza10': 30,
#  'BushiRoad': 30,
#  'Berkeley': 30,
#  'Milestone S.r.l': 30,
#  'Headup Games': 30,
#  'Vap': 30,
#  'HAL Laboratory': 30,
#  'Flight-Plan': 30,
#  'Essential Games': 30,
#  'Elite': 30,
#  'Grand Prix Games': 30,
#  'Shogakukan': 30,
#  'Gamebridge': 30,
#  'G.Rev': 30,
#  'Epic Games': 30,
#  'Mystique': 30,
#  'Quelle': 30,
#  'Nippon Amuse': 30,
#  'Seventh Chord': 30,
#  'Hello Games': 30,
#  'WayForward Technologies': 30,
#  'Imadio': 30,
#  'Gameloft': 30,
#  'Evolution Games': 30,
#  'Warp': 30,
#  'Boost On': 30,
#  'Liquid Games': 30,
#  'Game Life': 30,
#  'Sweets': 30,
#  'Paon Corporation': 30,
#  '2D Boy': 30,
#  'FunSoft': 30,
#  'Playmore': 30,
#  'Mirai Shounen': 30,
#  'Codemasters Online': 30,
#  'responDESIGN': 30,
#  'New World Computing': 30,
#  'UEP Systems': 30,
#  'Rain Games': 30,
#  'MediaQuest': 30,
#  'SSI': 30,
#  'Misawa': 30,
#  'Pioneer LDC': 30,
#  'Tigervision': 30,
#  'CTO SpA': 30,
#  'Revolution Software': 30}

# %%
pub_dict_str = {v:(k if v < 30 else "Other") for k, v in pub_dict.items()}

# %%
pub_dict_str
# Out:
# {0: 'Electronic Arts',
#  1: 'Ubisoft',
#  2: 'Activision',
#  3: 'Namco Bandai Games',
#  4: 'Konami Digital Entertainment',
#  5: 'Sony Computer Entertainment',
#  6: 'THQ',
#  7: 'Nintendo',
#  8: 'Sega',
#  9: 'Take-Two Interactive',
#  10: 'Capcom',
#  11: 'Atari',
#  12: 'Tecmo Koei',
#  13: 'Warner Bros. Interactive Entertainment',
#  14: 'Square Enix',
#  15: 'Unknown',
#  16: 'Disney Interactive Studios',
#  17: 'Eidos Interactive',
#  18: 'Midway Games',
#  19: '505 Games',
#  20: 'Microsoft Game Studios',
#  21: 'D3Publisher',
#  22: 'Acclaim Entertainment',
#  23: 'Vivendi Games',
#  24: 'Codemasters',
#  25: 'Deep Silver',
#  26: 'Idea Factory',
#  27: 'Zoo Digital Publishing',
#  28: 'Nippon Ichi Software',
#  29: 'Hudson Soft',
#  30: 'Other'}

# %%
df_num = X_train.replace(genr_dict)
df_num.Publisher = df_num.Publisher.replace(pub_dict)
df_num.Platform = df_num.Platform.replace(plat_dict)

# %%
df_num
# Out:
#         Rank                                        Name  Platform    Year  \
# 9837    9839  Gungnir: Mayari no Gunshin to Eiyuu Sensou         5  2011.0
# 12334  12336                 Famicom Mini: Balloon Fight         8  2004.0
# 14412  14415           Mother Goose no Himitsu no Yakata         5  2011.0
# 531      532          Dragon Quest V: Tenkuu no Hanayome        15  1992.0
# 8089    8091                              Jampack Vol. 1         6  1996.0
# ...      ...                                         ...       ...     ...
# 1232    1234                                   NASCAR 98         6  1996.0
# 13034  13036        Doraemon: Nobita no Kyouryuu 2006 DS         0  2006.0
# 12025  12027                     AMF Bowling Pinbusters!         0  2008.0
# 9484    9486                       Rango: The Video Game         4  2011.0
# 13656  13658                         Pac-Man World Rally         5  2006.0
#
#        Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 9837       3       30.0      0.07      0.00      0.04         0.01
# 12334      0        7.0      0.00      0.00      0.06         0.00
# 14412      5       30.0      0.00      0.00      0.03         0.00
# 531        3       30.0      0.00      0.00      2.78         0.01
# 8089       2        5.0      0.10      0.07      0.00         0.01
# ...      ...        ...       ...       ...       ...          ...
# 1232       6        0.0      1.43      0.05      0.00         0.04
# 13034      3        8.0      0.00      0.00      0.05         0.00
# 12025      1       30.0      0.06      0.00      0.00         0.00
# 9484       0        0.0      0.06      0.06      0.00         0.01
# 13656      6        3.0      0.04      0.00      0.00         0.00
#
#        Global_Sales
# 9837           0.12
# 12334          0.06
# 14412          0.03
# 531            2.79
# 8089           0.18
# ...             ...
# 1232           1.52
# 13034          0.05
# 12025          0.07
# 9484           0.13
# 13656          0.04
#
# [11618 rows x 11 columns]

# %%
df_num.corr()
# Out:
#                   Rank  Platform      Year     Genre  Publisher  NA_Sales  \
# Rank          1.000000 -0.037216  0.174860  0.084906   0.344048 -0.450279
# Platform     -0.037216  1.000000 -0.292375  0.007817   0.015866  0.037093
# Year          0.174860 -0.292375  1.000000 -0.128614  -0.027864 -0.098695
# Genre         0.084906  0.007817 -0.128614  1.000000   0.110218 -0.023834
# Publisher     0.344048  0.015866 -0.027864  0.110218   1.000000 -0.143417
# NA_Sales     -0.450279  0.037093 -0.098695 -0.023834  -0.143417  1.000000
# EU_Sales     -0.412288 -0.010747  0.009376 -0.028435  -0.140987  0.744439
# JP_Sales     -0.261929  0.149951 -0.175809  0.028299  -0.052289  0.406502
# Other_Sales  -0.332200 -0.069335  0.041160 -0.042102  -0.122797  0.592440
# Global_Sales -0.469386  0.038727 -0.080219 -0.021163  -0.148249  0.928381
#
#               EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank         -0.412288 -0.261929    -0.332200     -0.469386
# Platform     -0.010747  0.149951    -0.069335      0.038727
# Year          0.009376 -0.175809     0.041160     -0.080219
# Genre        -0.028435  0.028299    -0.042102     -0.021163
# Publisher    -0.140987 -0.052289    -0.122797     -0.148249
# NA_Sales      0.744439  0.406502     0.592440      0.928381
# EU_Sales      1.000000  0.433385     0.646636      0.895115
# JP_Sales      0.433385  1.000000     0.248113      0.603330
# Other_Sales   0.646636  0.248113     1.000000      0.707637
# Global_Sales  0.895115  0.603330     0.707637      1.000000

# %% [markdown]
# ### correlation을 통해 알게된 정보
# - 유럽과 북미는 매우 강한 선형관계를 갖는 것에 비해 일본은 비교적 약한 선형관계를 갖고있음
# - 일본의 경우는 발매 플랫폼에 따른 판매량의 선형관계가 보이는 반면 나머지 국가들은 퍼블리셔에 따른 선형관계가 보임

# %% [markdown]
# ### 가설 2 : 북미 판매량이 세계 판매량과 가장 밀접한 관계가 있을 것이다
# - correlation을 통해 북미의 판매량과 세계 판매량이 약 0.94의 상관계수를 갖는 것으로 가장 강한 선형관계를 보이고 있음
# - 따라서 다른 지역에 비해 북미의 판매량이 세계의 판매량과 연관성이 높음

# %% [markdown]
# ## 퍼블리셔별

# %%
df_pub = df_num.copy()

# %%
df_pub.Publisher = df_pub.Publisher.replace(pub_dict_str)

# %%
df_pub
# Out:
#         Rank                                        Name  Platform    Year  \
# 9837    9839  Gungnir: Mayari no Gunshin to Eiyuu Sensou         5  2011.0
# 12334  12336                 Famicom Mini: Balloon Fight         8  2004.0
# 14412  14415           Mother Goose no Himitsu no Yakata         5  2011.0
# 531      532          Dragon Quest V: Tenkuu no Hanayome        15  1992.0
# 8089    8091                              Jampack Vol. 1         6  1996.0
# ...      ...                                         ...       ...     ...
# 1232    1234                                   NASCAR 98         6  1996.0
# 13034  13036        Doraemon: Nobita no Kyouryuu 2006 DS         0  2006.0
# 12025  12027                     AMF Bowling Pinbusters!         0  2008.0
# 9484    9486                       Rango: The Video Game         4  2011.0
# 13656  13658                         Pac-Man World Rally         5  2006.0
#
#        Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 9837       3                        Other      0.07      0.00      0.04
# 12334      0                     Nintendo      0.00      0.00      0.06
# 14412      5                        Other      0.00      0.00      0.03
# 531        3                        Other      0.00      0.00      2.78
# 8089       2  Sony Computer Entertainment      0.10      0.07      0.00
# ...      ...                          ...       ...       ...       ...
# 1232       6              Electronic Arts      1.43      0.05      0.00
# 13034      3                         Sega      0.00      0.00      0.05
# 12025      1                        Other      0.06      0.00      0.00
# 9484       0              Electronic Arts      0.06      0.06      0.00
# 13656      6           Namco Bandai Games      0.04      0.00      0.00
#
#        Other_Sales  Global_Sales
# 9837          0.01          0.12
# 12334         0.00          0.06
# 14412         0.00          0.03
# 531           0.01          2.79
# 8089          0.01          0.18
# ...            ...           ...
# 1232          0.04          1.52
# 13034         0.00          0.05
# 12025         0.00          0.07
# 9484          0.01          0.13
# 13656         0.00          0.04
#
# [11618 rows x 11 columns]

# %%
df_pub_mean = df_pub.groupby("Publisher").mean()

# %%
df_pub_mean
# Out:
#                                                 Rank  Platform         Year  \
# Publisher
# 505 Games                                9794.161765  2.750000  2008.470588
# Acclaim Entertainment                    8181.663866  8.310924  1999.924370
# Activision                               6543.204545  5.395455  2007.317972
# Atari                                    8236.250996  6.569721  2002.600823
# Capcom                                   7866.775665  6.802281  2005.899614
# Codemasters                              9166.186916  4.850467  2008.019048
# D3Publisher                             11545.225806  3.580645  2009.161290
# Deep Silver                             10425.793478  5.195652  2011.076087
# Disney Interactive Studios               5742.120000  3.913333  2008.925676
# Eidos Interactive                        7993.266187  4.690647  2004.330935
# Electronic Arts                          5217.882476  5.280168  2006.465536
# Hudson Soft                              9062.876923  8.153846  2002.292308
# Idea Factory                            14475.413793  5.885057  2011.523256
# Konami Digital Entertainment             8823.520478  5.191126  2005.457831
# Microsoft Game Studios                   6046.795455  7.704545  2006.750000
# Midway Games                             7716.572464  6.188406  2003.301471
# Namco Bandai Games                       9352.803200  5.636800  2008.269231
# Nintendo                                 4035.699170  9.578838  2003.985325
# Nippon Ichi Software                    10481.694444  6.750000  2011.972222
# Other                                   10700.255527  5.728869  2006.006892
# Sega                                     7951.270742  7.722707  2005.557269
# Sony Computer Entertainment              5927.757937  4.065476  2004.533730
# Square Enix                              6636.524691  4.876543  2010.125000
# THQ                                      6556.101833  4.649695  2006.077551
# Take-Two Interactive                     6503.929329  4.703180  2008.081560
# Tecmo Koei                              10817.067511  4.848101  2008.227848
# Ubisoft                                  7447.640483  5.111782  2007.915152
# Unknown                                 11186.064516  4.870968  2009.765432
# Vivendi Games                            8073.711864  5.423729  2004.379310
# Warner Bros. Interactive Entertainment   5459.041176  6.647059  2011.918750
# Zoo Digital Publishing                  11416.960000  4.493333  2005.640000
#
#                                            Genre  NA_Sales  EU_Sales  \
# Publisher
# 505 Games                               4.904412  0.172279  0.089853
# Acclaim Entertainment                   4.445378  0.217899  0.080504
# Activision                              2.736364  0.413985  0.221985
# Atari                                   4.605578  0.270837  0.074183
# Capcom                                  3.650190  0.197300  0.102624
# Codemasters                             4.822430  0.073551  0.157103
# D3Publisher                             3.387097  0.068226  0.030565
# Deep Silver                             4.380435  0.095326  0.068043
# Disney Interactive Studios              2.600000  0.330467  0.168067
# Eidos Interactive                       3.294964  0.254245  0.167842
# Electronic Arts                         3.144806  0.454502  0.268510
# Hudson Soft                             4.215385  0.038462  0.014308
# Idea Factory                            4.011494  0.005517  0.000345
# Konami Digital Entertainment            3.129693  0.109625  0.079744
# Microsoft Game Studios                  4.363636  0.912121  0.392879
# Midway Games                            3.434783  0.218551  0.080507
# Namco Bandai Games                      3.945600  0.074528  0.046528
# Nintendo                                4.809129  1.006680  0.525622
# Nippon Ichi Software                    3.027778  0.049583  0.019444
# Other                                   4.390117  0.109672  0.055205
# Sega                                    3.755459  0.178581  0.143537
# Sony Computer Entertainment             3.565476  0.398492  0.281587
# Square Enix                             3.179012  0.183519  0.120741
# THQ                                     4.266802  0.296619  0.136151
# Take-Two Interactive                    2.459364  0.553746  0.301237
# Tecmo Koei                              3.004219  0.043207  0.023376
# Ubisoft                                 4.006042  0.285514  0.193233
# Unknown                                 4.200000  0.093097  0.032710
# Vivendi Games                           4.415254  0.254237  0.103644
# Warner Bros. Interactive Entertainment  1.405882  0.366412  0.244176
# Zoo Digital Publishing                  4.533333  0.087600  0.022000
#
#                                         JP_Sales  Other_Sales  Global_Sales
# Publisher
# 505 Games                               0.011544     0.029265      0.304044
# Acclaim Entertainment                   0.007731     0.015882      0.322521
# Activision                              0.006939     0.076167      0.719455
# Atari                                   0.032988     0.025538      0.404622
# Capcom                                  0.198897     0.038403      0.537529
# Codemasters                             0.003925     0.038505      0.273832
# D3Publisher                             0.027258     0.012500      0.138710
# Deep Silver                             0.008261     0.022935      0.194457
# Disney Interactive Studios              0.001867     0.057200      0.558600
# Eidos Interactive                       0.013453     0.042878      0.478633
# Electronic Arts                         0.010609     0.093694      0.827366
# Hudson Soft                             0.213538     0.004923      0.271077
# Idea Factory                            0.027126     0.001034      0.034138
# Konami Digital Entertainment            0.110546     0.034488      0.334625
# Microsoft Game Studios                  0.015909     0.109621      1.430455
# Midway Games                            0.000870     0.024420      0.325362
# Namco Bandai Games                      0.137904     0.015760      0.274832
# Nintendo                                0.609523     0.112033      2.253859
# Nippon Ichi Software                    0.060694     0.013333      0.141389
# Other                                   0.051440     0.016505      0.233254
# Sega                                    0.088952     0.040677      0.451812
# Sony Computer Entertainment             0.115714     0.123909      0.919861
# Square Enix                             0.189630     0.045556      0.539444
# THQ                                     0.005886     0.046212      0.484868
# Take-Two Interactive                    0.015866     0.152191      1.022862
# Tecmo Koei                              0.082152     0.010211      0.158903
# Ubisoft                                 0.008776     0.059230      0.547009
# Unknown                                 0.018968     0.010258      0.155032
# Vivendi Games                           0.001949     0.031102      0.391017
# Warner Bros. Interactive Entertainment  0.004588     0.081588      0.696765
# Zoo Digital Publishing                  0.001867     0.007333      0.118667

# %%
sales = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]

# %%
mean_sales_by_pub = df_pub_mean[sales].sort_values("Global_Sales", ascending=False)

# %%
mean_sales_by_pub
# Out:
#                                         NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo                                1.006680  0.525622  0.609523
# Microsoft Game Studios                  0.912121  0.392879  0.015909
# Take-Two Interactive                    0.553746  0.301237  0.015866
# Sony Computer Entertainment             0.398492  0.281587  0.115714
# Electronic Arts                         0.454502  0.268510  0.010609
# Activision                              0.413985  0.221985  0.006939
# Warner Bros. Interactive Entertainment  0.366412  0.244176  0.004588
# Disney Interactive Studios              0.330467  0.168067  0.001867
# Ubisoft                                 0.285514  0.193233  0.008776
# Square Enix                             0.183519  0.120741  0.189630
# Capcom                                  0.197300  0.102624  0.198897
# THQ                                     0.296619  0.136151  0.005886
# Eidos Interactive                       0.254245  0.167842  0.013453
# Sega                                    0.178581  0.143537  0.088952
# Atari                                   0.270837  0.074183  0.032988
# Vivendi Games                           0.254237  0.103644  0.001949
# Konami Digital Entertainment            0.109625  0.079744  0.110546
# Midway Games                            0.218551  0.080507  0.000870
# Acclaim Entertainment                   0.217899  0.080504  0.007731
# 505 Games                               0.172279  0.089853  0.011544
# Namco Bandai Games                      0.074528  0.046528  0.137904
# Codemasters                             0.073551  0.157103  0.003925
# Hudson Soft                             0.038462  0.014308  0.213538
# Other                                   0.109672  0.055205  0.051440
# Deep Silver                             0.095326  0.068043  0.008261
# Tecmo Koei                              0.043207  0.023376  0.082152
# Unknown                                 0.093097  0.032710  0.018968
# Nippon Ichi Software                    0.049583  0.019444  0.060694
# D3Publisher                             0.068226  0.030565  0.027258
# Zoo Digital Publishing                  0.087600  0.022000  0.001867
# Idea Factory                            0.005517  0.000345  0.027126
#
#                                         Other_Sales  Global_Sales
# Publisher
# Nintendo                                   0.112033      2.253859
# Microsoft Game Studios                     0.109621      1.430455
# Take-Two Interactive                       0.152191      1.022862
# Sony Computer Entertainment                0.123909      0.919861
# Electronic Arts                            0.093694      0.827366
# Activision                                 0.076167      0.719455
# Warner Bros. Interactive Entertainment     0.081588      0.696765
# Disney Interactive Studios                 0.057200      0.558600
# Ubisoft                                    0.059230      0.547009
# Square Enix                                0.045556      0.539444
# Capcom                                     0.038403      0.537529
# THQ                                        0.046212      0.484868
# Eidos Interactive                          0.042878      0.478633
# Sega                                       0.040677      0.451812
# Atari                                      0.025538      0.404622
# Vivendi Games                              0.031102      0.391017
# Konami Digital Entertainment               0.034488      0.334625
# Midway Games                               0.024420      0.325362
# Acclaim Entertainment                      0.015882      0.322521
# 505 Games                                  0.029265      0.304044
# Namco Bandai Games                         0.015760      0.274832
# Codemasters                                0.038505      0.273832
# Hudson Soft                                0.004923      0.271077
# Other                                      0.016505      0.233254
# Deep Silver                                0.022935      0.194457
# Tecmo Koei                                 0.010211      0.158903
# Unknown                                    0.010258      0.155032
# Nippon Ichi Software                       0.013333      0.141389
# D3Publisher                                0.012500      0.138710
# Zoo Digital Publishing                     0.007333      0.118667
# Idea Factory                               0.001034      0.034138

# %%
pub_plot = df_num.groupby("Publisher").mean()[sales]

# %%
for s in pub_plot.drop("Global_Sales", axis=1).columns:
    plt.title("Mean Sales by Publisher")
    plt.plot(pub_plot.index, pub_plot[s], label=s)
    plt.legend()
plt.xlabel('Publisher')
plt.ylabel("Mean Salse (in million)")
plt.show()

# %% [markdown]
# ### 가설 1 : 나라별로 선호하는 플랫폼과 게임 장르 및 퍼블리셔가 다를 것이다
# - 위의 그래프와 표는 각 퍼블리셔의 지역별 판매량을 평균낸 것
# - 이를 통해서 북미와 유럽은 선호하는 퍼블리셔가 대체로 동일하고 일본의 경우는 선호하는 퍼블리셔가 다름을 알 수 있음
#   - 북미와 유럽은 EA 나 Activision 등의 게임을 많이 소비하지만 일본은 그렇지 않고 오히려 자국의 게임을 더 많이 소비함

# %% [markdown]
# ## 장르별

# %%
df_gen = df_num.copy()

# %%
df_gen.Genre = df_pub.Genre.replace(genr_dict_str)

# %%
df_gen
# Out:
#         Rank                                        Name  Platform    Year  \
# 9837    9839  Gungnir: Mayari no Gunshin to Eiyuu Sensou         5  2011.0
# 12334  12336                 Famicom Mini: Balloon Fight         8  2004.0
# 14412  14415           Mother Goose no Himitsu no Yakata         5  2011.0
# 531      532          Dragon Quest V: Tenkuu no Hanayome        15  1992.0
# 8089    8091                              Jampack Vol. 1         6  1996.0
# ...      ...                                         ...       ...     ...
# 1232    1234                                   NASCAR 98         6  1996.0
# 13034  13036        Doraemon: Nobita no Kyouryuu 2006 DS         0  2006.0
# 12025  12027                     AMF Bowling Pinbusters!         0  2008.0
# 9484    9486                       Rango: The Video Game         4  2011.0
# 13656  13658                         Pac-Man World Rally         5  2006.0
#
#               Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 9837   Role-Playing       30.0      0.07      0.00      0.04         0.01
# 12334        Action        7.0      0.00      0.00      0.06         0.00
# 14412     Adventure       30.0      0.00      0.00      0.03         0.00
# 531    Role-Playing       30.0      0.00      0.00      2.78         0.01
# 8089           Misc        5.0      0.10      0.07      0.00         0.01
# ...             ...        ...       ...       ...       ...          ...
# 1232         Racing        0.0      1.43      0.05      0.00         0.04
# 13034  Role-Playing        8.0      0.00      0.00      0.05         0.00
# 12025        Sports       30.0      0.06      0.00      0.00         0.00
# 9484         Action        0.0      0.06      0.06      0.00         0.01
# 13656        Racing        3.0      0.04      0.00      0.00         0.00
#
#        Global_Sales
# 9837           0.12
# 12334          0.06
# 14412          0.03
# 531            2.79
# 8089           0.18
# ...             ...
# 1232           1.52
# 13034          0.05
# 12025          0.07
# 9484           0.13
# 13656          0.04
#
# [11618 rows x 11 columns]

# %%
df_gen_mean = df_gen.groupby("Genre").mean()

# %%
df_gen_mean
# Out:
#                       Rank  Platform         Year  Publisher  NA_Sales  \
# Genre
# Action         7968.397596  5.950193  2007.901704  12.432200  0.270434
# Adventure     11547.982063  4.950673  2008.169875  20.074324  0.089955
# Fighting       7807.864028  6.549053  2004.503509  14.547496  0.260017
# Misc           8559.104651  4.243355  2007.373109  14.556684  0.221520
# Platform       7043.696284  7.494346  2003.782324  11.589951  0.458239
# Puzzle         9817.239401  5.084788  2005.428934  19.112219  0.153666
# Racing         7947.223489  5.803877  2004.967366  14.922374  0.294914
# Role-Playing   8117.725746  6.255597  2006.936792  17.137255  0.201996
# Shooter        7393.830508  6.294492  2005.845820  13.144374  0.428676
# Simulation     8579.072368  3.942434  2006.651591  13.308072  0.216118
# Sports         7376.618781  5.594527  2005.635384   9.865421  0.292991
# Strategy      10089.875776  6.107660  2005.618947  14.891892  0.114720
#
#               EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action        0.161417  0.046119     0.059618      0.537789
# Adventure     0.051536  0.041334     0.013666      0.196637
# Fighting      0.114785  0.108227     0.043098      0.526007
# Misc          0.112500  0.061653     0.039834      0.435797
# Platform      0.216721  0.129225     0.054071      0.858643
# Puzzle        0.079227  0.088628     0.019327      0.341671
# Racing        0.198723  0.046043     0.066956      0.606956
# Role-Playing  0.123545  0.229170     0.037799      0.592584
# Shooter       0.232023  0.028210     0.076261      0.765572
# Simulation    0.127730  0.068059     0.036003      0.448158
# Sports        0.160386  0.058800     0.054235      0.566660
# Strategy      0.073851  0.066439     0.018406      0.273830

# %%
df_gen_mean[sales].sort_values("Global_Sales", ascending=False)
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Platform      0.458239  0.216721  0.129225     0.054071      0.858643
# Shooter       0.428676  0.232023  0.028210     0.076261      0.765572
# Racing        0.294914  0.198723  0.046043     0.066956      0.606956
# Role-Playing  0.201996  0.123545  0.229170     0.037799      0.592584
# Sports        0.292991  0.160386  0.058800     0.054235      0.566660
# Action        0.270434  0.161417  0.046119     0.059618      0.537789
# Fighting      0.260017  0.114785  0.108227     0.043098      0.526007
# Simulation    0.216118  0.127730  0.068059     0.036003      0.448158
# Misc          0.221520  0.112500  0.061653     0.039834      0.435797
# Puzzle        0.153666  0.079227  0.088628     0.019327      0.341671
# Strategy      0.114720  0.073851  0.066439     0.018406      0.273830
# Adventure     0.089955  0.051536  0.041334     0.013666      0.196637

# %%
gen_plot = df_num.groupby("Genre").mean()[sales]

# %%
gen_plot
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# 0      0.270434  0.161417  0.046119     0.059618      0.537789
# 1      0.292991  0.160386  0.058800     0.054235      0.566660
# 2      0.221520  0.112500  0.061653     0.039834      0.435797
# 3      0.201996  0.123545  0.229170     0.037799      0.592584
# 4      0.428676  0.232023  0.028210     0.076261      0.765572
# 5      0.089955  0.051536  0.041334     0.013666      0.196637
# 6      0.294914  0.198723  0.046043     0.066956      0.606956
# 7      0.458239  0.216721  0.129225     0.054071      0.858643
# 8      0.216118  0.127730  0.068059     0.036003      0.448158
# 9      0.260017  0.114785  0.108227     0.043098      0.526007
# 10     0.114720  0.073851  0.066439     0.018406      0.273830
# 11     0.153666  0.079227  0.088628     0.019327      0.341671

# %%
for s in df_gen_mean[sales].drop("Global_Sales", axis=1).index:
    plt.title(f"Mean Sales by {s} Genre")
    gen_plot[s]
    plt.pie(gen_plot[sales], labels=s)
    plt.legend()
    plt.xlabel('Genre')
    plt.ylabel("Mean Salse (in million)")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Action'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [108], in <cell line: 1>()
#       1 for s in df_gen_mean[sales].drop("Global_Sales", axis=1).index:
#       2     plt.title(f"Mean Sales by {s} Genre")
# ----> 3     gen_plot[s]
#       4     plt.pie(gen_plot[s], labels=s)
#       5     plt.legend()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Action'

# %%
for s in gen_plot.drop("Global_Sales", axis=1).columns:
    plt.title("Mean Sales by Genre")
    plt.bar(gen_plot.index, gen_plot[s], label=s, alpha=0.6)
    print(s)
    plt.legend()
plt.xlabel('Genre')
plt.ylabel("Mean Salse (in million)")
plt.show()
# Out:
# NA_Sales
# EU_Sales
# JP_Sales
# Other_Sales

# %%
genr_dict
# Out:
# {'Action': 0,
#  'Sports': 1,
#  'Misc': 2,
#  'Role-Playing': 3,
#  'Shooter': 4,
#  'Adventure': 5,
#  'Racing': 6,
#  'Platform': 7,
#  'Simulation': 8,
#  'Fighting': 9,
#  'Strategy': 10,
#  'Puzzle': 11}

# %% [markdown]
# ### 가설 1 : 나라별로 선호하는 플랫폼과 게임 장르 및 퍼블리셔가 다를 것이다
# - 위의 그래프와 표는 각 장르의 지역별 판매량을 평균낸 것
# - 이를 통해서 북미와 유럽은 선호하는 장르가 대체로 동일하고 일본의 경우는 선호하는 장르가 다름을 알 수 있음
#   - 일본이 다른 지역보다 RPG에 대한 선호도가 굉장히 높음 반면 슈팅게임의 경우 일본의 선호도가 낮고 다른 지역의 선호도가 높음

# %% [markdown]
# ### 플랫폼별

# %%
df_plat = df_num.copy()

# %%
df_plat.Platform = df_plat.Platform.replace(plat_dict_str)

# %%
df_plat_mean = df_plat.groupby("Platform").mean()

# %%
df_plat_mean
# Out:
#                   Rank         Year     Genre  Publisher  NA_Sales  EU_Sales  \
# Platform
# 2600       4625.425287  1982.168831  2.839080  16.402299  0.589655  0.035862
# 3DO       14059.500000  1995.000000  6.500000  17.000000  0.000000  0.000000
# 3DS        9107.260745  2013.069767  3.137536  13.813218  0.123037  0.094785
# DC         8397.625000  2000.062500  4.562500  11.718750  0.153438  0.045312
# DS         9744.965077  2008.184228  4.568838  15.309764  0.171961  0.084876
# GB         3745.876712  1996.277778  5.465753  10.575342  1.041781  0.529041
# GBA        8847.198971  2003.265625  3.958834  13.139037  0.211715  0.081852
# GC         8821.605744  2003.341398  3.971279  10.864230  0.234648  0.066841
# GEN        7629.857143  1992.904762  4.904762  11.809524  0.665238  0.186190
# GG        13527.000000  1992.000000  7.000000   8.000000  0.000000  0.000000
# N64        6360.057778  1998.551570  4.275556  15.324444  0.441556  0.131956
# NES        1669.823529  1987.294118  5.161765  11.779412  1.221471  0.213824
# NG        10920.571429  1994.714286  9.000000  29.857143  0.000000  0.000000
# PC        11505.119293  2008.747006  5.169367  15.207101  0.103505  0.135700
# PCFX      14559.000000  1996.000000  3.000000  30.000000  0.000000  0.000000
# PS         6865.446556  1998.063397  4.390736  16.561383  0.301235  0.183100
# PS2        7478.706522  2004.566782  3.654212  13.280272  0.273872  0.159069
# PS3        6758.748702  2010.868783  2.844237  10.907388  0.306812  0.264341
# PS4        7531.911392  2015.025316  2.632911  13.506329  0.311350  0.402743
# PSP       10313.979429  2008.734954  3.989714  15.036655  0.089166  0.055234
# PSV       11333.442105  2013.943860  2.810526  18.720848  0.042842  0.042596
# SAT        9107.728070  1996.000000  5.438596  16.500000  0.006316  0.004737
# SCD       11520.333333  1994.000000  5.000000   8.000000  0.000000  0.000000
# SNES       6427.629412  1993.911765  4.588235  19.629412  0.230235  0.069588
# TG16      15538.000000  1995.000000  4.000000  29.000000  0.000000  0.000000
# WS         7291.500000  1999.750000  4.750000   9.750000  0.000000  0.000000
# Wii        7779.289474  2008.995676  3.427368  14.229715  0.340221  0.184611
# WiiU       8072.098039  2013.549020  2.529412   8.470588  0.219510  0.145588
# X360       6739.801362  2009.877765  2.988649  12.092360  0.465426  0.220204
# XB         8787.862847  2003.649910  3.763889  13.335069  0.223924  0.072535
# XOne       7130.321678  2014.762238  2.671329  12.853147  0.412378  0.234406
#
#           JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600      0.000000     0.005517      0.631954
# 3DO       0.040000     0.000000      0.040000
# 3DS       0.184384     0.019742      0.422063
# DC        0.166250     0.007188      0.372812
# DS        0.074359     0.026521      0.358059
# GB        0.882055     0.073973      2.526575
# GBA       0.054837     0.008491      0.357513
# GC        0.033760     0.008930      0.345222
# GEN       0.090476     0.028571      0.970476
# GG        0.040000     0.000000      0.040000
# N64       0.109244     0.014622      0.698000
# NES       0.980294     0.059706      2.475441
# NG        0.111429     0.000000      0.111429
# PC        0.000250     0.025302      0.265464
# PCFX      0.030000     0.000000      0.030000
# PS        0.115831     0.035297      0.635273
# PS2       0.060666     0.091230      0.584878
# PS3       0.060955     0.109543      0.741599
# PS4       0.044177     0.136371      0.894430
# PSP       0.065223     0.034377      0.244057
# PSV       0.053123     0.022070      0.160561
# SAT       0.204386     0.000614      0.215965
# SCD       0.083333     0.000000      0.083333
# SNES      0.473294     0.012706      0.785706
# TG16      0.020000     0.000000      0.020000
# WS        0.220000     0.000000      0.220000
# Wii       0.046137     0.053916      0.625442
# WiiU      0.065392     0.033922      0.465196
# X360      0.010238     0.066617      0.762736
# XB        0.001389     0.010694      0.309167
# XOne      0.001818     0.059720      0.707832

# %%
df_plat_mean[sales].sort_values("Global_Sales", ascending=False)
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# GB        1.041781  0.529041  0.882055     0.073973      2.526575
# NES       1.221471  0.213824  0.980294     0.059706      2.475441
# GEN       0.665238  0.186190  0.090476     0.028571      0.970476
# PS4       0.311350  0.402743  0.044177     0.136371      0.894430
# SNES      0.230235  0.069588  0.473294     0.012706      0.785706
# X360      0.465426  0.220204  0.010238     0.066617      0.762736
# PS3       0.306812  0.264341  0.060955     0.109543      0.741599
# XOne      0.412378  0.234406  0.001818     0.059720      0.707832
# N64       0.441556  0.131956  0.109244     0.014622      0.698000
# PS        0.301235  0.183100  0.115831     0.035297      0.635273
# 2600      0.589655  0.035862  0.000000     0.005517      0.631954
# Wii       0.340221  0.184611  0.046137     0.053916      0.625442
# PS2       0.273872  0.159069  0.060666     0.091230      0.584878
# WiiU      0.219510  0.145588  0.065392     0.033922      0.465196
# 3DS       0.123037  0.094785  0.184384     0.019742      0.422063
# DC        0.153438  0.045312  0.166250     0.007188      0.372812
# DS        0.171961  0.084876  0.074359     0.026521      0.358059
# GBA       0.211715  0.081852  0.054837     0.008491      0.357513
# GC        0.234648  0.066841  0.033760     0.008930      0.345222
# XB        0.223924  0.072535  0.001389     0.010694      0.309167
# PC        0.103505  0.135700  0.000250     0.025302      0.265464
# PSP       0.089166  0.055234  0.065223     0.034377      0.244057
# WS        0.000000  0.000000  0.220000     0.000000      0.220000
# SAT       0.006316  0.004737  0.204386     0.000614      0.215965
# PSV       0.042842  0.042596  0.053123     0.022070      0.160561
# NG        0.000000  0.000000  0.111429     0.000000      0.111429
# SCD       0.000000  0.000000  0.083333     0.000000      0.083333
# 3DO       0.000000  0.000000  0.040000     0.000000      0.040000
# GG        0.000000  0.000000  0.040000     0.000000      0.040000
# PCFX      0.000000  0.000000  0.030000     0.000000      0.030000
# TG16      0.000000  0.000000  0.020000     0.000000      0.020000

# %%
plat_plot = df_num.groupby("Platform").mean()[sales]

# %%
for s in plat_plot.drop("Global_Sales", axis=1).columns:
    plt.title("Mean Sales by Platform")
    plt.bar(plat_plot.index, plat_plot[s], label=s, alpha=0.7)
    plt.legend()
plt.xlabel('Platform')
plt.ylabel("Mean Salse (in million)")
plt.show()

# %% [markdown]
# ### 가설 1 : 나라별로 선호하는 플랫폼과 게임 장르 및 퍼블리셔가 다를 것이다
# - 위의 그래프와 표는 각 플랫폼의 지역별 판매량을 평균낸 것
# - 이를 통해서 북미와 유럽 그리고 일본이 선호하는 플랫폼에 차이가 있는 것을 볼 수 있음
#   - 일본은 다른 지역에 비해 Xbox 시리즈를 선호하지 않는 반면 유럽의 경우 다른 지역들 보다 PC에 대한 선호도가 높음

# %%
df_num.Year.unique()
# Out:
# array([2011., 2004., 1992., 1996., 2008., 2007., 2001., 2005., 2012.,
#        2010., 1998., 2016., 2000., 2015., 2013., 2002., 2006., 1982.,
#        1990.,   nan, 2009., 2014., 1997., 2003., 1999., 1995., 1991.,
#        1983., 1994., 1981., 1985., 1989., 1993., 1988., 1987., 1984.,
#        2017., 1980., 1986., 2020.])

# %% [markdown]
# ### 연도별

# %%
df_year = df_num.copy()

# %%
years = sorted(df_year.Year.unique())

# %%
years
# Out:
# [1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  nan,
#  2017.0,
#  2020.0]

# %%
test_year = df_year.loc[df_year.Year == 1983.0]
test_year
# Out:
#       Rank                      Name  Platform    Year  Genre  Publisher  \
# 4267  4269                  Gremlins        19  1983.0      0       11.0
# 6007  6009                   Dolphin        19  1983.0      0        2.0
# 4096  4098                 Millipede        19  1983.0      4       11.0
# 2672  2674           Crystal Castles        19  1983.0      0       11.0
# 2652  2654               Jr. Pac-Man        19  1983.0     11       11.0
# 5559  5561   Frogger II: Threeedeep!        19  1983.0      0       30.0
# 5382  5384                 Frostbite        19  1983.0      0        2.0
# 763    765                   Mahjong        21  1983.0      2        7.0
# 8457  8459          Mr. Do!'s Castle        19  1983.0      0       30.0
# 1809  1811               Donkey Kong        21  1983.0      7        7.0
# 421    422                  Baseball        21  1983.0      1        7.0
# 1508  1510  Pitfall II: Lost Caverns        19  1983.0      7        2.0
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4267      0.43      0.03      0.00         0.00          0.46
# 6007      0.27      0.02      0.00         0.00          0.29
# 4096      0.45      0.03      0.00         0.01          0.48
# 2672      0.72      0.04      0.00         0.01          0.77
# 2652      0.72      0.05      0.00         0.01          0.78
# 5559      0.31      0.02      0.00         0.00          0.33
# 5382      0.32      0.02      0.00         0.00          0.34
# 763       0.01      0.00      2.13         0.00          2.14
# 8457      0.15      0.01      0.00         0.00          0.17
# 1809      0.23      0.05      0.84         0.01          1.13
# 421       0.73      0.10      2.35         0.02          3.20
# 1508      1.22      0.07      0.00         0.02          1.31

# %%
for y in years:
    df_yplot = df_year.loc[df_year.Year == y]
    ypub_plot = df_yplot.groupby("Publisher").mean()[sales]
    for s in ypub_plot.drop("Global_Sales", axis=1).columns:
        plt.title(f"Mean Sales by Publisher in {y}")
        plt.bar(ypub_plot.index, ypub_plot[s], label=s)
        plt.legend()
    plt.xlabel('Publisher')
    plt.ylabel("Mean Salse (in million)")
    plt.show()

# %%
test_year = df_year.loc[df_year.Year == 2017.0]

# %%
test_year.groupby("Publisher").mean()[sales]
# Out:
#            NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Publisher
# 8.0             0.0       0.0      0.02          0.0          0.02
# 26.0            0.0       0.0      0.01          0.0          0.01
